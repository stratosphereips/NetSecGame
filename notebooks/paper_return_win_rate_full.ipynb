# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.style.use('default')
plt.style.use('fivethirtyeight')
plt.style.use('seaborn-v0_8-white')

# %%
models = ["Random", "RandomHeur", "Q-Learning", "LLM", "LLM ReAct"]
max_steps = [30, 60, 100]

# %% [markdown]
# ## No Defender

# %% [markdown]
# ### Return

# %%
random_mean = [-27.480, -44.465, -57.488]
random_heur_mean = [-15.563, -9.190, -9.213]
q_agent_mean = [32.071, 48.001, 47.644]
llm_mean = [-15.000, -33.500, -57.033]
llm_qa_mean = [61.533, 77.133, 77.133]

# %%
plt.rcParams.update({'font.size': 20})

x = np.arange(len(max_steps))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(16, 8))
rects2 = ax.bar(x - width/2, random_mean, width/4, capsize=5, label='Random')
rects2 = ax.bar(x - width/4, random_heur_mean, width/4, capsize=5, label='Random Heur')
rects3 = ax.bar(x, q_agent_mean, width/4, capsize=5, label='Q Learning')
rects4 = ax.bar(x + width/4, llm_mean, width/4, label='LLM (One-shot)')
rects5 = ax.bar(x + width/2, llm_qa_mean, width/4, capsize=5, label='LLM (ReAct)')
ax.set_ylabel('Average Return')
ax.set_xlabel('Max Steps')
ax.set_xticks(x)
ax.set_xticklabels(max_steps)
# ax.set_yticks(range(10, 110, 10))


ax.legend(loc=(1.02, 0.3))
ax.yaxis.grid(True, linestyle='-.')

fig.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(8, 8))

plt.plot(max_steps, random_mean, marker=".", label="Random")
plt.plot(max_steps, random_heur_mean, marker="d", label="Random Heur")
plt.plot(max_steps, q_agent_mean, marker="o", label="Q-Agent")
plt.plot(max_steps, llm_mean, marker="*", label="LLM (One-shot)")
plt.plot(max_steps, llm_qa_mean, marker="^", label="LLM (ReAct)")

plt.grid(axis='y')
plt.ylabel("Average Return")
plt.xlabel("Max Steps")
plt.xticks(max_steps)
plt.ylim(-100, 100)
plt.legend()

ax.legend(loc=(1.02, 0.3))
ax.yaxis.grid(True, linestyle='-.')
# plt.title("Average Return - No Defender")

# %% [markdown]
# ### Win Rate

# %%
random_mean = [3.53, 19.43, 40.99]
random_heur_mean = [13.59, 41.32, 60.53]
q_agent_mean = [58.442, 58.741, 56.843]
llm_mean = [13.33, 20., 26.667]
llm_qa_mean = [83.333, 100, 100]

# %%
plt.rcParams.update({'font.size': 20})

x = np.arange(len(max_steps))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(16, 8))
rects2 = ax.bar(x - width/2, random_mean, width/4, capsize=5, label='Random')
rects2 = ax.bar(x - width/4, random_heur_mean, width/4, capsize=5, label='Random Heur')
rects3 = ax.bar(x, q_agent_mean, width/4, capsize=5, label='Q-learning')
# rects4 = ax.bar(x + width/4, llm_mean, width/4, label='LLM (One-shot)')
rects5 = ax.bar(x + width/4, llm_qa_mean, width/4, capsize=5, label='LLM (ReAct)')
ax.set_ylabel('Win Rate (%)')
ax.set_xlabel('Max Steps')
ax.set_xticks(x)
ax.set_xticklabels(max_steps)
# ax.set_yticks(range(10, 110, 10))


ax.legend(loc=(1.02, 0.3))
ax.yaxis.grid(True, linestyle='-.')
# plt.ylim(0, 100)


fig.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(8, 8))

plt.plot(max_steps, random_mean, marker=".", label="Random")
plt.plot(max_steps, random_heur_mean, marker="d", label="Random Heur")
plt.plot(max_steps, q_agent_mean, marker="*", label="Q Learning")
plt.plot(max_steps, llm_mean, marker="*", label="LLM (One-shot)")
plt.plot(max_steps, llm_qa_mean, marker="*", label="LLM (ReAct)")


plt.grid(axis='y')
plt.ylabel("Win Rate (%)")
plt.xlabel("Max Steps")
plt.xticks(max_steps)
# plt.ylim(0, 100)
plt.legend()

ax.legend(loc=(1.02, 0.3))
ax.yaxis.grid(True, linestyle='-.')
# plt.title("Win Rate - No Defender")

# %% [markdown]
# ## With Defender

# %% [markdown]
# ### Return

# %%
random_mean = [-55.285, -65.112, -66.562]
random_heur_mean = [-48.825, -52.964, -54.209]
q_agent_mean = [42.568, 45.375, 42.949]
llm_mean = [-45.067, -52.700, -52.700]
llm_qa_mean = [8.300, 8.200, 8.800]

# %%
plt.rcParams.update({'font.size': 20})

x = np.arange(len(max_steps))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(16, 8))
rects2 = ax.bar(x - width/2, random_mean, width/4, capsize=5, label='Random')
rects2 = ax.bar(x - width/4, random_heur_mean, width/4, capsize=5, label='Random Heur')
rects3 = ax.bar(x, q_agent_mean, width/4, capsize=5, label='Q Learning')
rects4 = ax.bar(x + width/4, llm_mean, width/4, label='LLM (one-shot)')
rects5 = ax.bar(x + width/2, llm_qa_mean, width/4, capsize=5, label='LLM ReAct')
ax.set_ylabel('Average Return')
ax.set_xlabel('Max Steps')
ax.set_xticks(x)
ax.set_xticklabels(max_steps)
# ax.set_yticks(range(10, 110, 10))


ax.legend(loc=(1.02, 0.3))
ax.yaxis.grid(True, linestyle='-.')
# plt.ylim(0, 100)


fig.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(8, 8))

plt.plot(max_steps, random_mean, marker=".", label="Random")
plt.plot(max_steps, random_heur_mean, marker="d", label="Random Heur")
plt.plot(max_steps, q_agent_mean, marker="*", label="Q-Agent")
plt.plot(max_steps, llm_mean, marker="*", label="LLM (One-shot)")
plt.plot(max_steps, llm_qa_mean, marker="*", label="LLM (ReAct)")


plt.grid(axis='y')
plt.ylabel("Average Return")
plt.xlabel("Max Steps")
plt.xticks(max_steps)
# plt.ylim(0, 100)
plt.legend()

ax.legend(loc=(1.02, 0.3))
ax.yaxis.grid(True, linestyle='-.')
# plt.title("Average Return - Stochastic w Threshold Defender")

# %% [markdown]
# ### Win Rate

# %%
random_mean = [0.98, 2.18, 2.72]
random_heur_mean = [5.02, 9.63, 11.19]
q_agent_mean = [65.474, 71.628, 71.568]
llm_mean = [10, 10, 10]
llm_qa_mean = [43.333, 50.0, 53.333]

# %%
plt.rcParams.update({'font.size': 20})

x = np.arange(len(max_steps))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(16, 8))
rects2 = ax.bar(x - width/2, random_mean, width/4, capsize=5, label='Random')
rects2 = ax.bar(x - width/4, random_heur_mean, width/4, capsize=5, label='Random Heur')
rects3 = ax.bar(x, q_agent_mean, width/4, capsize=5, label='Q-learning')
# rects4 = ax.bar(x + width/4, llm_mean, width/4, label='LLM (One-shot)')
rects5 = ax.bar(x + width/4, llm_qa_mean, width/4, capsize=5, label='LLM (ReAct)')
ax.set_ylabel('Win Rate (%)')
ax.set_xlabel('Max Steps')
ax.set_xticks(x)
ax.set_xticklabels(max_steps)
# ax.set_yticks(range(10, 110, 10))


ax.legend(loc=(1.02, 0.3))
ax.yaxis.grid(True, linestyle='-.')
# plt.ylim(0, 100)


fig.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(8, 8))

plt.plot(max_steps, random_mean, marker=".", label="Random")
plt.plot(max_steps, random_heur_mean, marker="d", label="Random Heur")
plt.plot(max_steps, q_agent_mean, marker="*", label="Q-Agent")
plt.plot(max_steps, llm_mean, marker="*", label="LLM (One-shot)")
plt.plot(max_steps, llm_qa_mean, marker="*", label="LLM (ReAct)")


plt.grid(axis='y')
plt.ylabel("Win Rate (%)")
plt.xlabel("Max Steps")
plt.xticks(max_steps)
# plt.ylim(0, 100)
plt.legend()

ax.legend(loc=(1.02, 0.3))
ax.yaxis.grid(True, linestyle='-.')
# plt.title("Win Rate - Stochastic w Threshold Defender")
